# %%
from MNIST_complex import plot_experiment

# %%
# HISTORY_DIR = "history/complex_init/std5"
HISTORY_DIR = "history/complex/std2"

# %%
plot_experiment(
    log_dir=HISTORY_DIR,
    metric="train_loss",
    compare_by="activation",
    fixed_params={"learning_rate": 0.1, "optimizer": "SGD"},
    semilogy=True,
)
# Out:
# Found 64 log files.

# %%
plot_experiment(
    log_dir=HISTORY_DIR,
    metric="train_loss",
    compare_by="activation",
    fixed_params={"learning_rate": 0.01, "optimizer": "Adam"},
    semilogy=True,
)
# Out:
# Found 22 log files.

# %%
plot_experiment(
    log_dir=HISTORY_DIR,
    metric="grad_norm",
    compare_by="learning_rate",
    fixed_params={"activation": "modrelu", "optimizer": "Adam"},
    semilogy=True,
)
# Out:
# Found 22 log files.

# %%
plot_experiment(
    log_dir=HISTORY_DIR,
    metric="grad_norm",
    compare_by="learning_rate",
    fixed_params={"activation": "cardioid", "optimizer": "Adam"},
    semilogy=True,
)
# Out:
# Found 22 log files.

# %%
plot_experiment(
    log_dir=HISTORY_DIR,
    metric="grad_norm",
    compare_by="optimizer",
    fixed_params={"learning_rate": 0.1, "activation": "modrelu"},
    semilogy=True,
)
# Out:
# Found 64 log files.

# %%
plot_experiment(
    log_dir=HISTORY_DIR,
    metric="grad_norm",
    compare_by="optimizer",
    fixed_params={"learning_rate": 0.1, "activation": "cardioid"},
    semilogy=True,
)
# Out:
# Found 64 log files.

# %%
plot_experiment(
    log_dir=HISTORY_DIR,
    metric="val_acc",
    compare_by="activation",
    fixed_params={"learning_rate": 0.01, "optimizer": "SGD"},
    semilogy=False,
)
# Out:
# Found 23 log files.
