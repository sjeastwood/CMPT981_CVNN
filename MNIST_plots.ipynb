# %%
from MNIST_complex import plot_experiment

# %%
HISTORY_DIR = "history/complex/std2"

# %%
plot_experiment(
    log_dir=HISTORY_DIR,
    metric="train_loss",
    compare_by="activation",
    fixed_params={"learning_rate": 0.001, "optimizer": "Adam"},
    semilogy=True,
)
# Out:
# Found 17 log files.

# %%
plot_experiment(
    log_dir=HISTORY_DIR,
    metric="grad_norm",
    compare_by="optimizer",
    fixed_params={"learning_rate": 0.001, "activation": "cardioid"},
    semilogy=True,
)
# Out:
# Found 17 log files.

# %%
plot_experiment(
    log_dir=HISTORY_DIR,
    metric="train_acc",
    compare_by="learning_rate",
    fixed_params={"activation": "cardioid", "optimizer": "Adam"},
    semilogy=False,
)
# Out:
# Found 17 log files.
